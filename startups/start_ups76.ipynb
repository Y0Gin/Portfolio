# %% [markdown]
# ФИО: Нагорянский Олег Николаевич
# ТГ: Y0Gin

# %% [markdown]
# <h1> Прогнозирование будущего компаний стартапов</h1>

# %% [markdown]
# Цель:
# <br/>
# 🔸Разработать модель машинного обучения для предсказания продолжения деятельности стартапа.
# <br/>
# 🔸Провести полноценный разведочный анализ и сформировать рекомендации будущим создателям стартапов (какие факторы влияют на успешность стартапа).
# <br/>
# Задачи:
# <br/>загрузка и ознакомление с данными,
# <br/>предварительная обработка,
# <br/>полноценный разведочный анализ,
# <br/>разработка новых синтетических признаков,
# <br/>проверка на мультиколлинеарность,
# <br/>отбор финального набора обучающих признаков,
# <br/>выбор и обучение моделей,
# <br/>итоговая оценка качества предсказания лучшей модели,
# <br/>анализ важности ее признаков,
# <br/>подготовка отчета по исследованию.
#
# Описание данных:
# <br/>kaggle_startups_train_01.csv - информация (53 000) стартапах, которые будут использоваться в качестве обучающих данных.
# <br/>kaggle_startups_test_01.csv - информация (13 000) стартапах, которые будут использоваться в качестве тестовых данных.
# <br/>kaggle_startups_sample_submit_01.csv - файл с примером предсказаний в правильном формате.
# <br/>name - идентификатор (название) стартапа в тестовом наборе.
# <br/>status - целевой признак. Для каждого стартапа предсказать категориальное значение соответствующее прогнозу ['operating', 'closed'].
#
# Описание полей:
# <br/>name - Название стартапа
# <br/>category_list - Список категорий, к которым относится стартап
# <br/>funding_total_usd - Общая сумма финансирования в USD
# <br/>status - Статус стартапа (закрыт или действующий)
# <br/>country_code - Код страны
# <br/>state_code - Код штата
# <br/>region - Регион
# <br/>city - Город
# <br/>funding_rounds - Количество раундов финансирования
# <br/>founded_at - Дата основания
# <br/>first_funding_at - Дата первого раунда финансирования
# <br/>last_funding_at - Дата последнего раунда финансирования
# <br/>closed_at - Дата закрытия стартапа (если применимо)
# <br/>lifetime - Время существования стартапа в днях

# %%
# !pip install phik -q
# !pip install shap -q
# !pip install -U scikit-learn
# !pip install catboost
# Out:
# Requirement already satisfied: scikit-learn in c:\users\admin\anaconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\admin\anaconda3\lib\site-packages (from scikit-learn) (1.9.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\admin\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\admin\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\admin\anaconda3\lib\site-packages (from scikit-learn) (1.21.5)
# Requirement already satisfied: catboost in c:\users\admin\anaconda3\lib\site-packages (1.2.5)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\admin\anaconda3\lib\site-packages (from catboost) (1.21.5)
# Requirement already satisfied: scipy in c:\users\admin\anaconda3\lib\site-packages (from catboost) (1.9.1)
# Requirement already satisfied: plotly in c:\users\admin\anaconda3\lib\site-packages (from catboost) (5.9.0)
# Requirement already satisfied: graphviz in c:\users\admin\anaconda3\lib\site-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in c:\users\admin\anaconda3\lib\site-packages (from catboost) (3.5.2)
# Requirement already satisfied: six in c:\users\admin\anaconda3\lib\site-packages (from catboost) (1.16.0)
# Requirement already satisfied: pandas>=0.24 in c:\users\admin\anaconda3\lib\site-packages (from catboost) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas>=0.24->catboost) (2022.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib->catboost) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib->catboost) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib->catboost) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib->catboost) (9.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\admin\anaconda3\lib\site-packages (from plotly->catboost) (8.0.1)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
import seaborn as sns
import phik
from sklearn.preprocessing import (
    OneHotEncoder, 
    OrdinalEncoder, 
    StandardScaler, 
    MinMaxScaler, 
    RobustScaler, 
    LabelEncoder,
    FunctionTransformer)
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score,
    confusion_matrix,
    recall_score,
    precision_score
)
from sklearn.compose import ColumnTransformer

# загружаем функцию для работы с метриками
from sklearn.metrics import roc_auc_score, f1_score

# импортируем класс RandomizedSearchCV
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

# загружаем нужные модели
from sklearn.linear_model import LogisticRegression, Lasso
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.dummy import DummyRegressor, DummyClassifier
from sklearn.svm import SVC

# загружаем класс для работы с пропусками
from sklearn.impute import SimpleImputer

# загружаем нужные классы
from sklearn.pipeline import Pipeline

from scipy import stats as st
import scipy.stats as sps
import shap
from catboost import CatBoostClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
from datetime import date, datetime
import time

# %% [markdown]
# <h2>Загрузка данных</h2>

# %%
df_train = pd.read_csv('kaggle_startups_train_28062024.csv')

# %%
df_test = pd.read_csv('kaggle_startups_test_28062024.csv')

# %%
df_train.head(10)
# Out:
#                         name  \
# 0                  Lunchgate
# 1                    EarLens
# 2     Reviva Pharmaceuticals
# 3       Sancilio and Company
# 4        WireTough Cylinders
# 5  Connected Sports Ventures
# 6                  Attensity
# 7              Mesh Networks
# 8                 AngioScore
# 9                 Vidatronic
#
#                                        category_list  funding_total_usd  \
# 0                    Online Reservations|Restaurants           828626.0
# 1              Manufacturing|Medical|Medical Devices         42935019.0
# 2                                      Biotechnology         35456381.0
# 3                                        Health Care         22250000.0
# 4                                      Manufacturing                NaN
# 5                                             Mobile          4300000.0
# 6  Analytics|Business Analytics|Social CRM|Social...         90000000.0
# 7                                           Software          4300000.0
# 8                                      Biotechnology         42000000.0
# 9                                     Semiconductors          1250500.0
#
#       status country_code state_code       region             city  \
# 0  operating          CHE         25       Zurich           Zürich
# 1  operating          USA         CA  SF Bay Area     Redwood City
# 2  operating          USA         CA  SF Bay Area         San Jose
# 3  operating          NaN        NaN          NaN              NaN
# 4  operating          USA         VA   VA - Other          Bristol
# 5  operating          USA         NJ       Newark        Princeton
# 6  operating          USA         CA  SF Bay Area     Redwood City
# 7  operating          USA         TX      Houston          Houston
# 8  operating          USA         CA  SF Bay Area          Fremont
# 9  operating          USA         TX       Austin  College Station
#
#    funding_rounds  founded_at first_funding_at last_funding_at closed_at
# 0               2  2009-10-17       2011-05-01      2014-12-01       NaN
# 1               4  2005-01-01       2010-05-04      2014-02-25       NaN
# 2               3  2006-01-01       2012-08-20      2014-07-02       NaN
# 3               3  2004-01-01       2011-09-01      2014-07-18       NaN
# 4               1  2010-05-12       2012-02-01      2012-02-01       NaN
# 5               1  2011-04-16       2012-11-12      2012-11-12       NaN
# 6               1  2000-01-01       2014-05-14      2014-05-14       NaN
# 7               1  2005-01-01       2014-11-09      2014-11-09       NaN
# 8               2  2003-01-01       2007-10-09      2011-04-20       NaN
# 9               2  2010-01-01       2011-08-23      2013-03-21       NaN

# %% [markdown]
# df_test.head(10)

# %%
df_train.columns
# Out:
# Index(['name', 'category_list', 'funding_total_usd', 'status', 'country_code',
#        'state_code', 'region', 'city', 'funding_rounds', 'founded_at',
#        'first_funding_at', 'last_funding_at', 'closed_at'],
#       dtype='object')

# %%
df_test.columns
# Out:
# Index(['name', 'category_list', 'funding_total_usd', 'country_code',
#        'state_code', 'region', 'city', 'funding_rounds', 'first_funding_at',
#        'last_funding_at', 'lifetime'],
#       dtype='object')

# %% [markdown]
# Данные из таблиц kaggle_startups_train_28062024.csv, kaggle_startups_test_28062024.csv загружены в переменные типа DataFrame библиотеки Pandas. Состав полей таблиц соответствует описанию данных в проекте.

# %% [markdown]
# <h2>Предобработка данных</h2>

# %% [markdown]
# <h3>Общая информация</h3>

# %%
def data_info(data, data_name):
    print("Информация о столбцах таблицы ", data_name)
    display(data.info())
    print("Количество незаполненных значений в полях:")
    print(data.isna().sum())
    dupl = data.duplicated().sum()
    print("Количество дубликатов:", dupl)

# %%
def to_lower_case(data, list_cols):
    for col in list_cols:
        data[col] = data[col].apply(str.lower)
    return data

# %%
data_info(df_train, 'Тренировочная выборка')
# Out:
# Информация о столбцах таблицы  Тренировочная выборка
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52516 entries, 0 to 52515
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               52515 non-null  object
#  1   category_list      50051 non-null  object
#  2   funding_total_usd  42447 non-null  float64
#  3   status             52516 non-null  object
#  4   country_code       47014 non-null  object
#  5   state_code         45753 non-null  object
#  6   region             46157 non-null  object
#  7   city               46157 non-null  object
#  8   funding_rounds     52516 non-null  int64
#  9   founded_at         52516 non-null  object
#  10  first_funding_at   52516 non-null  object
#  11  last_funding_at    52516 non-null  object
#  12  closed_at          4917 non-null   object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 5.2+ MB
# None
# Количество незаполненных значений в полях:
# name                     1
# category_list         2465
# funding_total_usd    10069
# status                   0
# country_code          5502
# state_code            6763
# region                6359
# city                  6359
# funding_rounds           0
# founded_at               0
# first_funding_at         0
# last_funding_at          0
# closed_at            47599
# dtype: int64
# Количество дубликатов: 0

# %%
df_train['founded_at'] = pd.to_datetime(df_train['founded_at'] )

# %%
df_train['first_funding_at'] = pd.to_datetime(df_train['first_funding_at'] )

# %%
df_train['last_funding_at'] = pd.to_datetime(df_train['last_funding_at'] )

# %%
df_train['closed_at'] = pd.to_datetime(df_train['closed_at'] )

# %%
cols = ['category_list', 'status', 'country_code', 'region', 'city', 'funding_rounds']

# %%
df_train['status'].value_counts()
# Out:
# operating    47599
# closed        4917
# Name: status, dtype: int64

# %%
df_train['country_code'].value_counts()
# Out:
# USA    29702
# GBR     2925
# CAN     1540
# IND     1276
# CHN     1240
#        ...
# PSE        1
# SEN        1
# UZB        1
# GRD        1
# ZMB        1
# Name: country_code, Length: 134, dtype: int64

# %%
df_train['region'].value_counts()
# Out:
# SF Bay Area            6970
# New York City          2776
# Boston                 1890
# London                 1840
# Los Angeles            1513
#                        ...
# Helena                    1
# Castelfranco Veneto       1
# Taunton                   1
# Vevey                     1
# Doncaster                 1
# Name: region, Length: 1036, dtype: int64

# %%
df_train['city'].value_counts()
# Out:
# San Francisco    2824
# New York         2486
# London           1514
# Austin            609
# Palo Alto         607
#                  ...
# Beppu               1
# Idukki              1
# Reutlingen          1
# Sulphur             1
# Centreville         1
# Name: city, Length: 4477, dtype: int64

# %%
df_train['funding_rounds'].value_counts()
# Out:
# 1     33489
# 2      9816
# 3      4450
# 4      2189
# 5      1168
# 6       616
# 7       341
# 8       175
# 9       109
# 10       63
# 11       46
# 12       22
# 13        9
# 16        6
# 15        5
# 14        5
# 17        3
# 18        3
# 19        1
# Name: funding_rounds, dtype: int64

# %%
data_info(df_test, 'Тестовая выборка')
# Out:
# Информация о столбцах таблицы  Тестовая выборка
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13125 entries, 0 to 13124
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               13125 non-null  object
#  1   category_list      12534 non-null  object
#  2   funding_total_usd  10547 non-null  float64
#  3   country_code       11743 non-null  object
#  4   state_code         11430 non-null  object
#  5   region             11536 non-null  object
#  6   city               11538 non-null  object
#  7   funding_rounds     13125 non-null  int64
#  8   first_funding_at   13125 non-null  object
#  9   last_funding_at    13125 non-null  object
#  10  lifetime           13125 non-null  int64
# dtypes: float64(1), int64(2), object(8)
# memory usage: 1.1+ MB
# None
# Количество незаполненных значений в полях:
# name                    0
# category_list         591
# funding_total_usd    2578
# country_code         1382
# state_code           1695
# region               1589
# city                 1587
# funding_rounds          0
# first_funding_at        0
# last_funding_at         0
# lifetime                0
# dtype: int64
# Количество дубликатов: 0

# %%
df_test['first_funding_at'] = pd.to_datetime(df_test['first_funding_at'] )

# %%
df_test['last_funding_at'] = pd.to_datetime(df_test['last_funding_at'] )

# %% [markdown]
# Исходя из первичного анализа значений датафреймов, видны незаполненные поля в таблицах, также присутствует значительнео число различных категорий и стран. Поля со значениями дат в датафреймах изменены на типы dataframe.

# %% [markdown]
# <h3>Предобработка категорий</h3>

# %%
def def_category(lst_cat, cat_rating, rating=100):
    category = "unknown"
    for cat in lst_cat:
        cat = cat.strip()
        if (cat in cat_rating.keys()):
            if (cat_rating[cat] > rating):
                rating = cat_rating[cat]
                category = cat
    return category

# %%
def def_second_category(lst_cat, cat_rating, rating=100):
    category = def_category(lst_cat, cat_rating, rating)
    if (category == 'unknown'):
        return 'unknown'
    else:
        if (category in lst_cat):
            lst_cat.remove(category)         
    return def_category(lst_cat, cat_rating, rating)

# %%
def make_rating(df, df_):
    sr_df = pd.concat([df['category_list'], df_['category_list']])
    
    sr_df = df['category_list']
    sr_df = sr_df.fillna('unknown')
    sr_df = (sr_df
            .str.replace("&", "|", regex = True)
            .str.replace("-", "", regex = True) 
            .str.replace("+", "|", regex = True)
            .str.strip()
            .apply(str.lower))
    sr_df = (sr_df.str
             .replace("fintech","finance")
             .replace("ios","iphone")
             .replace("edtech","education")
             .replace("social network media","media")
             .replace("digital media","media")
             .replace("health care information technology","healthcare services")
             .replace("mobile games","games")
             .replace("educational games","games")
             .replace("casual games","games")
             .replace("video games","games")
             .replace("computers","video games")
             .replace("communications hardware","hardware")
             .replace("embedded hardware and software","hardware")
             .replace("enterprise hardware","hardware")
             .replace("health diagnostics","health care")
             .replace("mobile health","health care")
             .replace("personal health","health care")
             .replace("mhealth","health care")
             .replace("health and insurance","health care")
             .replace("health","health care") 
             .replace("health services industry","health care")
             .replace("senior health","health care")
             .replace("health and wellness","health care") 
             .replace("big data analytics","analytics") 
             .replace("predictive analytics","analytics") 
             .replace("business analytics","analytics") 
             .replace("mobile analytics","analytics")
             .replace("text analytics","analytics")
             .replace("medical professionals","medical")
             .replace("medical devices","analytics")
             .replace("online travel","travel")
             .replace("adventure travel","travel")
             .replace("social travel","travel")
             .replace("tourism","travel")
             .replace("television","video")
             .replace("video streaming","video")
             .replace("mobile video","video")
             .replace("video conferencing","video")
             .replace("video chat","video")
             .replace("mobile commerce","mobile")
             .replace("mobile payments","mobile")
             .replace("mobile advertising","mobile")
             .replace("mobile software tools","mobile")
             .replace("mobile devices","mobile")
            )
             
    div_symb = "|"
    lst_cat = sr_df.str.split(div_symb)
    cmnlst = list()
    for lst in lst_cat:
        cmnlst = cmnlst + lst
    sr_cat = pd.Series(cmnlst).apply(str.strip)  
    cat_rating = sr_cat.value_counts()
    return cat_rating

# %%
def pre_categories(df, cat_rating):
    df['category_list'] = df['category_list'].fillna('Unknown')
    df['category_list'] = (df['category_list']
            .str.replace("&", "|", regex = True)
            .str.replace("-", "", regex = True) 
            .str.replace("+", "|", regex = True)
            .str.strip()
            #.str.replace(' ', '')
            .apply(str.lower))
    df['category_list'] = (df['category_list'].str
             .replace("fintech","finance")
             .replace("ios","iphone")
             .replace("edtech","education")
             .replace("social network media","media")
             .replace("digital media","media")
             .replace("health care information technology","healthcare services")
             .replace("mobile games","games")
             .replace("educational games","games")
             .replace("casual games","games")
             .replace("video games","games")
             .replace("computers","video games")
             .replace("communications hardware","hardware")
             .replace("embedded hardware and software","hardware")
             .replace("enterprise hardware","hardware")
             .replace("health diagnostics","health care")
             .replace("mobile health","health care")
             .replace("personal health","health care")
             .replace("mhealth","health care")
             .replace("health and insurance","health care")
             .replace("health","health care") 
             .replace("health services industry","health care")
             .replace("senior health","health care")
             .replace("health","health care") 
             .replace("health services industry","health care")
             .replace("senior health","health care")
             .replace("health and wellness","health care") 
             .replace("big data analytics","analytics") 
             .replace("predictive analytics","analytics") 
             .replace("business analytics","analytics") 
             .replace("mobile analytics","analytics")
             .replace("text analytics","analytics")
             .replace("medical professionals","medical")
             .replace("medical devices","analytics")
             .replace("online travel","travel")
             .replace("adventure travel","travel")
             .replace("social travel","travel")
             .replace("tourism","travel")
             .replace("television","video")
             .replace("video streaming","video")
             .replace("mobile video","video")
             .replace("video conferencing","video")
             .replace("video chat","video")
             .replace("mobile commerce","mobile")
             .replace("mobile payments","mobile")
             .replace("mobile advertising","mobile")
             .replace("mobile software tools","mobile")
             .replace("mobile devices","mobile"))
    div_symb = "|"
    lst_cat = df['category_list'].str.split(div_symb) 
    df['category_list'] = lst_cat.apply(def_category, args=(cat_rating,500))    
    df['sec_category_list'] = lst_cat.apply(def_second_category, args=(cat_rating,2000))
    return df

# %%
df_train['category_list'].value_counts().head(10)
# Out:
# Software               3207
# Biotechnology          2905
# E-Commerce             1064
# Mobile                  920
# Clean Technology        892
# Curated Web             853
# Health Care             744
# Hardware + Software     733
# Games                   681
# Enterprise Software     671
# Name: category_list, dtype: int64

# %%
cat_rating = make_rating(df_train, df_test)

# %%
cat_rating.to_csv("cat_ratings.csv")

# %%
df_train = pre_categories(df_train, cat_rating)

# %%
df_test = pre_categories(df_test, cat_rating)

# %%
df_train['category_list'].value_counts()
# Out:
# software                  8154
# unknown                   7746
# mobile                    3958
# biotechnology             3654
# ecommerce                 2993
# health care               2188
# curated web               2095
# enterprise software       1638
# social media              1477
# games                     1425
# advertising               1275
# finance                   1251
# clean technology          1135
# education                 1032
# analytics                  906
# manufacturing              890
# internet                   792
# technology                 729
# services                   611
# security                   536
# travel                     486
# real estate                484
# consulting                 483
# semiconductors             451
# apps                       450
# hospitality                428
# medical                    427
# fashion                    365
# saas                       358
# web hosting                338
# marketplaces               310
# music                      240
# financial services         232
# news                       231
# sports                     230
# health and wellness        229
# information technology     227
# video                      225
# media                      221
# messaging                  217
# search                     212
# entertainment              189
# design                     175
# networking                 159
# retail                     128
# big data                   119
# startups                   117
# cloud computing            104
# hardware                    82
# social network media        74
# sales and marketing         40
# Name: category_list, dtype: int64

# %%
df_test['category_list'].value_counts()
# Out:
# software                  1995
# unknown                   1953
# mobile                    1008
# biotechnology              867
# ecommerce                  748
# health care                551
# curated web                529
# games                      389
# enterprise software        381
# social media               370
# advertising                309
# finance                    308
# clean technology           303
# education                  287
# manufacturing              240
# analytics                  234
# technology                 199
# internet                   196
# services                   169
# security                   131
# travel                     126
# consulting                 121
# real estate                120
# hospitality                116
# medical                    108
# fashion                    105
# semiconductors             104
# web hosting                 96
# apps                        91
# saas                        76
# marketplaces                74
# health and wellness         73
# messaging                   63
# information technology      62
# financial services          57
# search                      53
# video                       53
# music                       52
# sports                      50
# media                       50
# news                        42
# networking                  38
# entertainment               36
# retail                      33
# big data                    31
# startups                    29
# design                      27
# hardware                    24
# cloud computing             24
# social network media        16
# sales and marketing          8
# Name: category_list, dtype: int64

# %%
display(df_train.head())
# Out:
#                      name  category_list  funding_total_usd     status  \
# 0               Lunchgate        unknown           828626.0  operating
# 1                 EarLens  manufacturing         42935019.0  operating
# 2  Reviva Pharmaceuticals  biotechnology         35456381.0  operating
# 3    Sancilio and Company    health care         22250000.0  operating
# 4     WireTough Cylinders  manufacturing                NaN  operating
#
#   country_code state_code       region          city  funding_rounds  \
# 0          CHE         25       Zurich        Zürich               2
# 1          USA         CA  SF Bay Area  Redwood City               4
# 2          USA         CA  SF Bay Area      San Jose               3
# 3          NaN        NaN          NaN           NaN               3
# 4          USA         VA   VA - Other       Bristol               1
#
#   founded_at first_funding_at last_funding_at closed_at sec_category_list
# 0 2009-10-17       2011-05-01      2014-12-01       NaT           unknown
# 1 2005-01-01       2010-05-04      2014-02-25       NaT           unknown
# 2 2006-01-01       2012-08-20      2014-07-02       NaT           unknown
# 3 2004-01-01       2011-09-01      2014-07-18       NaT           unknown
# 4 2010-05-12       2012-02-01      2012-02-01       NaT           unknown

# %% [markdown]
# Исходя из анализа содержимого категориий установлено, что некоторые записи содержат последовательности нескольких категорий. Поэтому создан рейтинг категорий по числу встречаемых в датафрейме и для каждой записи выбирается наиболее часто встречаемая категория.

# %% [markdown]
# <h2>Исследовательский анализ данных</h2>

# %%
def category_exploration(data, lst_cols):
    if (len(lst_cols) == 1):
        cnt_col = "name"
    else: 
        cnt_col = lst_cols[-1]
    for col in lst_cols:
        a = data.groupby(col).agg({cnt_col:'count'}).reset_index().sort_values(by=cnt_col,ascending = False)
        a.columns = [col, 'количество_записей']
        a['Percentage'] = a['количество_записей'] / a['количество_записей'].sum()*100
        print(a.head(70))
        a.head(70).plot(kind='bar', xlabel=col, ylabel='Количество стартапов', x=col, y='количество_записей',
                              title='Количество стартапов в разрезе признака ' + col, figsize=(8,8))
        cnt_col = col

# %%
def numeric_exploration(data, lst_cols):
    for col in lst_cols:
        print('Статистическая информация по столбцу:', col)
        print(data[col].describe())
        plt.hist(data[col])
        plt.xlabel(col)
        plt.ylabel('Частота')
        plt.grid(True)
        plt.title('Гистограмма частот по признаку ' + col)
        plt.show()        
        data.boxplot(column=col, vert=False)
        plt.xlabel(col)
        plt.grid(True)
        plt.title('Распределение по квартилям (ящик с усами) для признака ' + col)
        plt.show()

# %%
def discrete_exploration(data, lst_cols):
    if (len(lst_cols) == 1):
        cnt_col = "name"
    else: 
        cnt_col = lst_cols[-1]
    for col in lst_cols:
        print('Статистическая информация по столбцу:', col)
        print(data[col].describe())
        a = data.groupby(col).agg({cnt_col:'count'}).reset_index()
        a.columns = [col, 'количество_записей']
        a['Percentage'] = a['количество_записей'] / a['количество_записей'].sum()*100
        print(a)
        
        sns.set(font_scale=1.3)
        plt.gcf().set_size_inches(8, 8)
        sns.countplot( x=col, data=data,color="salmon")
        
        plt.xlabel(col)
        plt.ylabel('Количество стартапов')
        
        plt.title('Количество стартапов в разрезе признака ' + col)  
        
        plt.show()
        cnt_col = col

# %% [markdown]
# <h3>Анализ категорийных признаков</h3>

# %%
lst_cols = ['category_list', 'status', 'country_code', 'region', 'city']

# %%
category_exploration(df_train, lst_cols)
# Out:
#              category_list  количество_записей  Percentage
# 43                software                7567   16.394046
# 48                 unknown                5788   12.539810
# 29                  mobile                3518    7.621813
# 4            biotechnology                3480    7.539485
# 10               ecommerce                2681    5.808436
# 20             health care                2027    4.391533
# 8              curated web                1883    4.079555
# 12     enterprise software                1548    3.353771
# 41            social media                1273    2.757978
# 17                   games                1251    2.710315
# 0              advertising                1173    2.541326
# 15                 finance                1143    2.476331
# 5         clean technology                1042    2.257512
# 11               education                 924    2.001863
# 1                analytics                 833    1.804710
# 24           manufacturing                 791    1.713716
# 23                internet                 642    1.390905
# 46              technology                 603    1.306411
# 38                security                 500    1.083259
# 40                services                 445    0.964101
# 33             real estate                 442    0.957601
# 7               consulting                 441    0.955435
# 47                  travel                 431    0.933770
# 39          semiconductors                 420    0.909938
# 21             hospitality                 391    0.847109
# 27                 medical                 373    0.808111
# 2                     apps                 343    0.743116
# 35                    saas                 317    0.686786
# 50             web hosting                 316    0.684620
# 14                 fashion                 314    0.680287
# 25            marketplaces                 268    0.580627
# 19     health and wellness                 214    0.463635
# 30                   music                 209    0.452802
# 32                    news                 204    0.441970
# 44                  sports                 199    0.431137
# 16      financial services                 198    0.428971
# 22  information technology                 194    0.420305
# 28               messaging                 194    0.420305
# 26                   media                 193    0.418138
# 49                   video                 191    0.413805
# 37                  search                 174    0.376974
# 13           entertainment                 158    0.342310
# 9                   design                 145    0.314145
# 31              networking                 144    0.311979
# 34                  retail                 113    0.244817
# 3                 big data                 111    0.240484
# 45                startups                  92    0.199320
# 6          cloud computing                  89    0.192820
# 18                hardware                  75    0.162489
# 42    social network media                  58    0.125658
# 36     sales and marketing                  34    0.073662
#       status  количество_записей  Percentage
# 1  operating               47599   90.637139
# 0     closed                4917    9.362861
#     country_code  количество_записей  Percentage
# 127          USA               29702   63.176926
# 39           GBR                2925    6.221551
# 19           CAN                1540    3.275620
# 52           IND                1276    2.714085
# 22           CHN                1240    2.637512
# ..           ...                 ...         ...
# 126          URY                  12    0.025524
# 112          SRB                  11    0.023397
# 42           GHA                  11    0.023397
# 81           MLT                   9    0.019143
# 64           KHM                   9    0.019143
#
# [70 rows x 3 columns]
#              region  количество_записей  Percentage
# 796     SF Bay Area                6970   15.100635
# 670   New York City                2776    6.014256
# 116          Boston                1890    4.094720
# 545          London                1840    3.986394
# 547     Los Angeles                1513    3.277943
# ..              ...                 ...         ...
# 698         Orlando                 123    0.266482
# 324  Ft. Lauderdale                 123    0.266482
# 215  Columbus, Ohio                 123    0.266482
# 823   Santa Barbara                 111    0.240484
# 845        Shenzhen                 110    0.238317
#
# [70 rows x 3 columns]
#                city  количество_записей  Percentage
# 3466  San Francisco                2824    6.118249
# 2724       New York                2486    5.385965
# 2238         London                1514    3.280109
# 179          Austin                 609    1.319410
# 2963      Palo Alto                 607    1.315077
# ...             ...                 ...         ...
# 1074         Durham                 122    0.264315
# 3862         Sydney                 119    0.257816
# 1549        Gurgaon                 112    0.242650
# 1358        Fremont                 112    0.242650
# 3746       St Louis                 112    0.242650
#
# [70 rows x 3 columns]

# %% [markdown]
# <h3>Анализ стран, регионов, городов и штатов</h3>

# %%
def ex_cou_sr(df, limit):
    s1 = df_train['country_code'].value_counts()
    s2 = df_test['country_code'].value_counts()
    s = pd.concat([s1,s2])
    return list(s[s < limit].index)

# %%
def ex_reg_sr(df, limit):
    s = df_train['region'].value_counts()
    return list(s[s < limit].index)

# %%
def ex_state_sr(df, limit):
    s = df_train['state_code'].value_counts()
    return list(s[s < limit].index)

# %%
def ex_city_sr(df, limit):
    s = df_train['city'].value_counts()
    return list(s[s < limit].index)

# %%
def limit_df(df, ex_cou, ex_reg, ex_state, ex_city):
    df['country_code'] = df['country_code'].fillna("OTH")
    df['country_code'] = df['country_code'].apply(lambda x: 'OTH' if x in ex_cou else x) 
    
    df['region'] = df['region'].apply(lambda x: 'OTH' if x in ex_reg else x) 
    df['state_code'] = df['state_code'].apply(lambda x: 'OTH' if x in ex_state else x) 
    df['city'] = df['city'].apply(lambda x: 'OTH' if x in ex_city else x) 
    return df

# %%
ex_cou = ex_cou_sr(df_train, 50)
ex_reg = ex_reg_sr(df_train, 50)
ex_state = ex_state_sr(df_train, 50)
ex_city = ex_city_sr(df_train, 50)

# %%
display(df_train['country_code'].value_counts())
display(df_train['region'].value_counts())
display(df_train['state_code'].value_counts())
# Out:
# USA    29702
# GBR     2925
# CAN     1540
# IND     1276
# CHN     1240
#        ...
# PSE        1
# SEN        1
# UZB        1
# GRD        1
# ZMB        1
# Name: country_code, Length: 134, dtype: int64
# SF Bay Area            6970
# New York City          2776
# Boston                 1890
# London                 1840
# Los Angeles            1513
#                        ...
# Helena                    1
# Castelfranco Veneto       1
# Taunton                   1
# Vevey                     1
# Doncaster                 1
# Name: region, Length: 1036, dtype: int64
# CA    10219
# NY     3112
# MA     2020
# TX     1562
# H9     1510
#       ...
# PE        1
# Y1        1
# O2        1
# V3        1
# U6        1
# Name: state_code, Length: 300, dtype: int64

# %%
df_train = limit_df(df_train, ex_cou, ex_reg, ex_state, ex_city)

# %%
display(df_train['country_code'].value_counts())
display(df_train['region'].value_counts())
display(df_train['state_code'].value_counts())
# Out:
# USA    29702
# OTH     8228
# GBR     2925
# CAN     1540
# IND     1276
# CHN     1240
# FRA      916
# DEU      834
# ISR      767
# ESP      607
# NLD      380
# AUS      379
# SWE      373
# RUS      369
# SGP      356
# BRA      355
# IRL      351
# ITA      321
# JPN      314
# KOR      300
# CHE      262
# CHL      252
# DNK      242
# FIN      227
# Name: country_code, dtype: int64
# OTH                    7541
# SF Bay Area            6970
# New York City          2776
# Boston                 1890
# London                 1840
#                        ...
# Louisville               53
# Jacksonville             53
# Tallinn                  51
# Pune                     50
# Rochester, New York      50
# Name: region, Length: 125, dtype: int64
# CA     10219
# NY      3112
# OTH     2235
# MA      2020
# TX      1562
#        ...
# 36        57
# ID        56
# B8        54
# VT        53
# 78        51
# Name: state_code, Length: 90, dtype: int64

# %%
df_test = limit_df(df_test, ex_cou, ex_reg, ex_state, ex_city)

# %%
display(df_test['country_code'].value_counts())
display(df_test['region'].value_counts())
display(df_test['state_code'].value_counts())
# Out:
# USA    7428
# OTH    2066
# GBR     725
# CAN     369
# IND     307
# CHN     301
# DEU     237
# FRA     213
# ISR     190
# ESP     134
# AUS     120
# NLD     112
# JPN      93
# SGP      91
# RUS      87
# BRA      85
# IRL      83
# CHL      80
# ITA      79
# SWE      75
# CHE      69
# DNK      68
# KOR      61
# FIN      52
# Name: country_code, dtype: int64
# OTH              1832
# SF Bay Area      1750
# New York City     712
# London            481
# Boston            460
#                  ...
# Picardie            1
# JOR - Other         1
# Castelldefels       1
# South Grafton       1
# SÃ¨te               1
# Name: region, Length: 179, dtype: int64
# CA     2552
# NY      789
# OTH     538
# MA      487
# TX      410
#        ...
# J5        1
# V9        1
# O3        1
# 75        1
# W3        1
# Name: state_code, Length: 101, dtype: int64

# %% [markdown]
# Исходя из анализа стран, регионов, штатов и городов, установлено, что есть значительное число различных объектов. Принято решение к отдельной категории OTH отнести объекты с общим числом появлений < 50

# %% [markdown]
# <h3>Новый признак</h3>

# %%
df_train.head(10)
# Out:
#                         name   category_list  funding_total_usd     status  \
# 0                  Lunchgate         unknown           828626.0  operating
# 1                    EarLens   manufacturing         42935019.0  operating
# 2     Reviva Pharmaceuticals   biotechnology         35456381.0  operating
# 3       Sancilio and Company     health care         22250000.0  operating
# 4        WireTough Cylinders   manufacturing                NaN  operating
# 5  Connected Sports Ventures          mobile          4300000.0  operating
# 6                  Attensity        software         90000000.0  operating
# 7              Mesh Networks        software          4300000.0  operating
# 8                 AngioScore   biotechnology         42000000.0  operating
# 9                 Vidatronic  semiconductors          1250500.0  operating
#
#   country_code state_code       region          city  funding_rounds  \
# 0          CHE         25       Zurich        Zürich               2
# 1          USA         CA  SF Bay Area  Redwood City               4
# 2          USA         CA  SF Bay Area      San Jose               3
# 3          OTH        NaN          NaN           NaN               3
# 4          USA         VA          OTH           OTH               1
# 5          USA         NJ       Newark           OTH               1
# 6          USA         CA  SF Bay Area  Redwood City               1
# 7          USA         TX      Houston       Houston               1
# 8          USA         CA  SF Bay Area       Fremont               2
# 9          USA         TX       Austin           OTH               2
#
#   founded_at first_funding_at last_funding_at closed_at sec_category_list
# 0 2009-10-17       2011-05-01      2014-12-01       NaT           unknown
# 1 2005-01-01       2010-05-04      2014-02-25       NaT           unknown
# 2 2006-01-01       2012-08-20      2014-07-02       NaT           unknown
# 3 2004-01-01       2011-09-01      2014-07-18       NaT           unknown
# 4 2010-05-12       2012-02-01      2012-02-01       NaT           unknown
# 5 2011-04-16       2012-11-12      2012-11-12       NaT           unknown
# 6 2000-01-01       2014-05-14      2014-05-14       NaT           unknown
# 7 2005-01-01       2014-11-09      2014-11-09       NaT           unknown
# 8 2003-01-01       2007-10-09      2011-04-20       NaT           unknown
# 9 2010-01-01       2011-08-23      2013-03-21       NaT           unknown

# %%
df_train['closed_at'] = pd.to_datetime(df_train['closed_at'].fillna('2018-01-01'))
df_train['lifetime'] = (df_train['closed_at'] - df_train['founded_at']).dt.days

# %%
df_train['lifetime'].head(5)
# Out:
# 0    2998
# 1    4748
# 2    4383
# 3    5114
# 4    2791
# Name: lifetime, dtype: int64

# %% [markdown]
# В тестовый датасет добавлено поле dateframe

# %% [markdown]
# <h3>Анализ количественных признаков</h3>

# %%
df_train.head(10)
# Out:
#                         name   category_list  funding_total_usd     status  \
# 0                  Lunchgate         unknown           828626.0  operating
# 1                    EarLens   manufacturing         42935019.0  operating
# 2     Reviva Pharmaceuticals   biotechnology         35456381.0  operating
# 3       Sancilio and Company     health care         22250000.0  operating
# 4        WireTough Cylinders   manufacturing                NaN  operating
# 5  Connected Sports Ventures          mobile          4300000.0  operating
# 6                  Attensity        software         90000000.0  operating
# 7              Mesh Networks        software          4300000.0  operating
# 8                 AngioScore   biotechnology         42000000.0  operating
# 9                 Vidatronic  semiconductors          1250500.0  operating
#
#   country_code state_code       region          city  funding_rounds  \
# 0          CHE         25       Zurich        Zürich               2
# 1          USA         CA  SF Bay Area  Redwood City               4
# 2          USA         CA  SF Bay Area      San Jose               3
# 3          OTH        NaN          NaN           NaN               3
# 4          USA         VA          OTH           OTH               1
# 5          USA         NJ       Newark           OTH               1
# 6          USA         CA  SF Bay Area  Redwood City               1
# 7          USA         TX      Houston       Houston               1
# 8          USA         CA  SF Bay Area       Fremont               2
# 9          USA         TX       Austin           OTH               2
#
#   founded_at first_funding_at last_funding_at  closed_at sec_category_list  \
# 0 2009-10-17       2011-05-01      2014-12-01 2018-01-01           unknown
# 1 2005-01-01       2010-05-04      2014-02-25 2018-01-01           unknown
# 2 2006-01-01       2012-08-20      2014-07-02 2018-01-01           unknown
# 3 2004-01-01       2011-09-01      2014-07-18 2018-01-01           unknown
# 4 2010-05-12       2012-02-01      2012-02-01 2018-01-01           unknown
# 5 2011-04-16       2012-11-12      2012-11-12 2018-01-01           unknown
# 6 2000-01-01       2014-05-14      2014-05-14 2018-01-01           unknown
# 7 2005-01-01       2014-11-09      2014-11-09 2018-01-01           unknown
# 8 2003-01-01       2007-10-09      2011-04-20 2018-01-01           unknown
# 9 2010-01-01       2011-08-23      2013-03-21 2018-01-01           unknown
#
#    lifetime
# 0      2998
# 1      4748
# 2      4383
# 3      5114
# 4      2791
# 5      2452
# 6      6575
# 7      4748
# 8      5479
# 9      2922

# %%
lst_cols = ['funding_total_usd', 'lifetime']

# %%
numeric_exploration(df_train, lst_cols)
# Out:
# Статистическая информация по столбцу: funding_total_usd
# count    4.244700e+04
# mean     1.824748e+07
# std      1.871173e+08
# min      1.000000e+00
# 25%      3.360275e+05
# 50%      2.000000e+06
# 75%      1.000000e+07
# max      3.007950e+10
# Name: funding_total_usd, dtype: float64
# Статистическая информация по столбцу: lifetime
# count    52516.000000
# mean      3140.828129
# std       2147.821070
# min         19.000000
# 25%       1739.000000
# 50%       2557.000000
# 75%       4018.000000
# max      17378.000000
# Name: lifetime, dtype: float64

# %%
df_train[df_train['funding_total_usd'] > 30000000000]
# Out:
#                          name category_list  funding_total_usd     status  \
# 39186  Verizon Communications        mobile       3.007950e+10  operating
#
#       country_code state_code         region      city  funding_rounds  \
# 39186          USA         NY  New York City  New York               5
#
#       founded_at first_funding_at last_funding_at  closed_at  \
# 39186 1983-10-07       2010-01-26      2014-02-28 2018-01-01
#
#       sec_category_list  lifetime
# 39186           unknown     12505

# %%
#df_train.loc[df_train['funding_total_usd'] > 30000000000, 'funding_total_usd'] = \
#df_train['funding_total_usd'].median()

# %%
df_train = df_train[~(df_train['funding_total_usd'] > 30000000000)]

# %%
#df_train = df_train[~df_train['funding_total_usd'].isna()]
#df_test['funding_total_usd'] = df_test['funding_total_usd'].fillna(df_train['funding_total_usd'].mean())

# %%
df_train['funding_total_usd'] = df_train['funding_total_usd'].fillna(df_train['funding_total_usd'].mean())
df_test['funding_total_usd'] = df_test['funding_total_usd'].fillna(df_train['funding_total_usd'].mean())

# %%
df_train['freq_fund'] = df_train['funding_total_usd'] / df_train['lifetime']
df_test['freq_fund'] =  df_test['funding_total_usd'] / df_test['lifetime']

# %%
df_train['life_per_round'] = df_train['lifetime'] / df_train['funding_rounds']
df_test['life_per_round'] = df_test['lifetime'] / df_test['funding_rounds']

# %%
df_train['fundtime'] = (df_train['last_funding_at'] - df_train['first_funding_at']).dt.days
df_test['fundtime'] = (df_test['last_funding_at'] - df_test['first_funding_at']).dt.days

# %%
df_train['fund_per_round'] = df_train['funding_total_usd'] / (df_train['funding_rounds']+1)
df_test['fund_per_round'] = df_test['funding_total_usd'] / (df_test['funding_rounds']+1)

# %%
df_train['koef_funding'] = df_train['fundtime'] / (df_train['lifetime']+1)
df_test['koef_funding'] = df_test['fundtime'] / (df_test['lifetime']+1)

# %%
df_train['x1'] = df_train['lifetime']**2
df_test['x1'] = df_test['lifetime']**2

# %%
df_train['x2'] = df_train['lifetime']**3
df_test['x2'] = df_test['lifetime']**3

# %%
df_train['x3'] = df_train['freq_fund']**3
df_test['x3'] = df_test['freq_fund']**3

# %%
df_train['x4'] = df_train['freq_fund']**2
df_test['x4'] = df_test['freq_fund']**2

# %%
df_train['x5'] = df_train['funding_total_usd']**2
df_test['x5'] = df_test['funding_total_usd']**2

# %%
df_train['x6'] = df_train['funding_total_usd']**3
df_test['x6'] = df_test['funding_total_usd']**3

# %%
df_train['x7'] = df_train['funding_total_usd'].apply(np.log)
df_test['x7'] = df_test['funding_total_usd'].apply(np.log)

# %%
df_train['x8'] = df_train['x7']*df_train['x2']
df_test['x8'] = df_test['x7']*df_test['x2']

# %% [markdown]
# Для дальнейшего анализа добавлены дополнительные признаки.

# %% [markdown]
# <h3>Анализ дискретных признаков</h3>

# %%
discrete_exploration(df_train, ['funding_rounds'])
# Out:
# Статистическая информация по столбцу: funding_rounds
# count    52515.000000
# mean         1.740607
# std          1.374462
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max         19.000000
# Name: funding_rounds, dtype: float64
#     funding_rounds  количество_записей  Percentage
# 0                1               33488   63.769661
# 1                2                9816   18.692158
# 2                3                4450    8.473931
# 3                4                2189    4.168412
# 4                5                1167    2.222265
# 5                6                 616    1.173021
# 6                7                 341    0.649351
# 7                8                 175    0.333244
# 8                9                 109    0.207564
# 9               10                  63    0.119968
# 10              11                  46    0.087596
# 11              12                  22    0.041894
# 12              13                   9    0.017138
# 13              14                   5    0.009521
# 14              15                   5    0.009521
# 15              16                   6    0.011426
# 16              17                   3    0.005713
# 17              18                   3    0.005713
# 18              19                   1    0.001904

# %% [markdown]
# Доп анализ

# %%
def Draw2(data, x_feature, y_feature, col):
    sns.set(font_scale=1.3)
    plt.xlabel(x_feature)
    plt.ylabel(y_feature)
    plt.gcf().set_size_inches(6, 6)
    sns.scatterplot(x=x_feature, y=y_feature, data=data, hue = col,  palette='bright', alpha=0.5)
   
    plt.show()

# %%
def Draw3(df, x_feature, x_name):
    df1 = df_train[df_train['status'] == 'operating']
    df2 = df_train[df_train['status'] == 'closed']
    sns.histplot(stat='density',common_norm=False, data=df1, x=x_feature, \
                alpha=0.5, bins=10, color='green', label='существующие стартапы')
    sns.histplot(stat='density', common_norm=False, color='blue', data=df2, x=x_feature, \
                 alpha=0.5, bins=10 , label='закрытые стартапы')
    plt.xlabel(x_name)
    plt.ylabel('Частота')
    plt.title('Сравнение распределений по признаку' + x_name)
    plt.grid(True)
    plt.rcParams["figure.figsize"] = (10,10)
    plt.legend()
    plt.show()

# %%
Draw3(df_train, "lifetime", "Время жизни")

# %%
df_op = df_train[df_train['status'] == 'operating']
df_cl = df_train[df_train['status'] == 'closed']

# %%
Draw2(df_cl, "lifetime", 'funding_total_usd', "status")

# %%
Draw2(df_op, "lifetime", 'funding_total_usd', "status")

# %%
Draw2(df_cl, 'freq_fund', "funding_total_usd" , "status")

# %%
Draw2(df_op, 'freq_fund', "funding_total_usd" , "status")

# %%
Draw2(df_op, 'fundtime', "lifetime" , "status")

# %%
Draw2(df_cl, 'fundtime', "lifetime" , "status")

# %% [markdown]
# <br/> Время жизни закрытых стартапов составляет по большей части менее 2000 дней согалсно графикам распределений.
# <br/>Чаще закрываются стартапы время жизни которых меньше 5000дней и сумма фонда меньше, чем 0,18*10e9.
# <br/>Чаще закрываются стартапы с параметром freq_fund < 180000.
# <br/> Чаще закрываются стартапы с временем фондирования fundtime меньшим 1000, при этом время жизни для них меньше 2500 дней.

# %% [markdown]
# <h3>Анализ корреляции</h3>

# %%
df_train_phik = df_train.sample(1000)

# %%
#M1 = df_train_phik.phik_matrix(interval_cols=['funding_total_usd', 'lifetime', 'freq_fund', 'fund_per_round', 'life_per_round', 'fundtime', 'koef_funding'])
#display(M1)

# %% [markdown]
# Высокая корреляция у прищнака Статус наблюдается с временем жизни, в меньшей степени категория и life_per_round. Даты из анализа исключаются.
# Регион, штат, город имеют высокую корреляцию с со страной, поэтому исключаются.

# %% [markdown]
# <h2>Подготовка и обучение моделей</h2>

# %%
RANDOM_STATE = 5

# %%
# создаём списки с названиями признаков
ohe_columns = [ 'category_list', 'country_code', 'sec_category_list'] #
ord_columns = ['funding_rounds']
num_columns = ['koef_funding', 'freq_fund','funding_total_usd'  ] #,'lifetime',

# %%
df_train_prep = df_train[ohe_columns+ord_columns+num_columns+['status']]
df_test_prep = df_test[ohe_columns+ord_columns+num_columns]

# %%
df_train_prep = df_train_prep.drop_duplicates()

# %%
X_train = df_train_prep.drop([ 'status'], axis=1)
data_info(X_train, "Тренировочная выборка")
# Out:
# Информация о столбцах таблицы  Тренировочная выборка
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50579 entries, 0 to 52515
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   category_list      50579 non-null  object
#  1   country_code       50579 non-null  object
#  2   sec_category_list  50579 non-null  object
#  3   funding_rounds     50579 non-null  int64
#  4   koef_funding       50579 non-null  float64
#  5   freq_fund          50579 non-null  float64
#  6   funding_total_usd  50579 non-null  float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 3.1+ MB
# None
# Количество незаполненных значений в полях:
# category_list        0
# country_code         0
# sec_category_list    0
# funding_rounds       0
# koef_funding         0
# freq_fund            0
# funding_total_usd    0
# dtype: int64
# Количество дубликатов: 35

# %%
y_train = df_train_prep['status']

# %%
X_test = df_test_prep
data_info(X_test, "Тестовая выборка")
# Out:
# Информация о столбцах таблицы  Тестовая выборка
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13125 entries, 0 to 13124
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   category_list      13125 non-null  object
#  1   country_code       13125 non-null  object
#  2   sec_category_list  13125 non-null  object
#  3   funding_rounds     13125 non-null  int64
#  4   koef_funding       13125 non-null  float64
#  5   freq_fund          13125 non-null  float64
#  6   funding_total_usd  13125 non-null  float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 717.9+ KB
# None
# Количество незаполненных значений в полях:
# category_list        0
# country_code         0
# sec_category_list    0
# funding_rounds       0
# koef_funding         0
# freq_fund            0
# funding_total_usd    0
# dtype: int64
# Количество дубликатов: 219

# %%
# создаем экземпляр класса LabelEncoder для кодирования целевого признака
label_encoder = LabelEncoder()
# обучаем модель и трансформируем тренировочную выборку 
y_train = label_encoder.fit_transform(y_train)

# %%
print(label_encoder.classes_)
# Out:
# ['closed' 'operating']

# %%
num_pipe = Pipeline(
    [('sc', MinMaxScaler()),
     ('num_fill_pipe', SimpleImputer(missing_values=np.nan, strategy='mean'))
    ]
    )

# %%
ord_pipe = Pipeline(
    [
    ('ord', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=np.nan)),
    ('ord_fill_pipe', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))
    ]
)

# %%
ohe_pipe = Pipeline(
    [
        ('none_fill_pipe', SimpleImputer(missing_values=np.nan,strategy='constant',\
                                    fill_value = 'Unknown')  ),  
        ('ohe', OneHotEncoder(drop='first', sparse_output=False, handle_unknown='infrequent_if_exist'))
    ]
    )

# %%
# создаём общий пайплайн для подготовки данных
data_preprocessor = ColumnTransformer(
    [('ohe', ohe_pipe, ohe_columns),
     ('ord', ord_pipe, ord_columns),
     ('num', num_pipe, num_columns)
    ], 
    remainder='passthrough'
)

# создаем итоговый пайплайн: подготовка данных и модель
pipe_final = Pipeline(
    [
        ('preprocessor', data_preprocessor),
        
        #('models', DecisionTreeClassifier( random_state=RANDOM_STATE, \
        #             max_depth = 5, max_features = 25, min_samples_leaf = 5)  )    
        ('models', CatBoostClassifier(iterations=1000, learning_rate=0.1, depth=6))
    
    ]
)

param_grid = [
             # словарь для модели DecisionTreeRegressor()
            #{
            #    'models': [DecisionTreeClassifier( )],
            #    'models__max_depth': np.arange(5,6,1),
            #    'models__max_features': np.arange(20,40,2),
            #    'models__min_samples_leaf': np.arange(3,8,2),
            #    'models__random_state': np.arange(1,100,1),
                #'preprocessor__num': [ MinMaxScaler()] #, StandardScaler(), 'passthrough'
            #},  
    
          # словарь для модели LogisticRegression()
          #  {
          #      'models': [LogisticRegression(
          #          random_state=RANDOM_STATE, 
          #          solver='liblinear', 
          #          penalty='l1'
          #      )],
          #       'models__C': np.arange(0.1,10.00,0.2),
                #'preprocessor__num': [MinMaxScaler(), 'passthrough']
          #  }
    
          #  {
          #       'models': [CatBoostClassifier(
          #          random_state=RANDOM_STATE, 
          #          iterations=2000, learning_rate=0.1, allow_writing_files=False
          #      )],
         #        'models__depth': np.arange(5,10,1),
                 #'models__random_state': np.arange(1,100,1),
                #'preprocessor__num': [MinMaxScaler(), 'passthrough']
          #  }
             {
                 'models': [RandomForestClassifier(
                    random_state=RANDOM_STATE, n_estimators = 100
                    
                )],
                 'models__max_depth': np.arange(5,10,1),
                 'models__max_features': np.arange(20,40,2),
                 #'models__random_state': np.arange(1,100,1),
                #'preprocessor__num': [MinMaxScaler(), 'passthrough']
            }
    
        ]

# %%
start_time = time.time()
grid = GridSearchCV(
            pipe_final, 
            param_grid=param_grid, 
            cv=7, 
            scoring="f1", 
            #random_state=RANDOM_STATE, 
            n_jobs = -1,
            error_score='raise'
)

# %%
grid.fit(X_train, y_train) 
print("--- %s seconds ---" % (time.time() - start_time))

# %%
grid

# %%
# проверяем работу модели на тестовой выборке
# рассчитываем прогноз на тестовых данных
y_train_pred = grid.predict(X_train)
display(y_train[0:100])
display(y_train_pred[0:100])
print(f'Метрика F1 на тренировочной выборке: {f1_score(y_train, y_train_pred)}')

# %%
y_test_pred = grid.predict(X_test)

# %%
label_encoder.inverse_transform(y_test_pred)

# %%
df_res = pd.DataFrame(df_test['name'])
df_res['status'] = label_encoder.inverse_transform(y_test_pred)
df_res.set_index('name', inplace=True)
df_res['status'].value_counts()

# %%
df_res.to_csv("first.csv")

# %%
import winsound
winsound.Beep(440, 2000)

# %%
dummy_model = DummyClassifier(strategy="most_frequent")
dummy_model.fit(X_train, y_train)
dummy_model_preds = dummy_model.predict_proba(X_train)

print(f'Метрика F1 на тестовой выборке для константной модели: {f1_score(y_train, dummy_model_preds[:,1])}')

# %% [markdown]
# <h2>Анализ результатов</h2>

# %%
best_pl = grid.best_estimator_
#best_pl = grid
X_test_scalled = pd.DataFrame(best_pl.named_steps['preprocessor'].transform(X_test))
X_train_scalled = pd.DataFrame(best_pl.named_steps['preprocessor'].transform(X_train))
best_model = best_pl.named_steps['models']
print(best_model)

# %%
X_test_scalled.columns = [ x[5:30] for x in best_pl[:-1].get_feature_names_out()]
X_train_scalled.columns = X_test_scalled.columns
X_test_scalled.columns

# %%
f = lambda x: best_model.predict_proba(x)[:,1]
med = X_train_scalled.median().values.reshape((1,X_train_scalled.shape[1]))
explainer = shap.KernelExplainer(f, med)
shap_values_norm = explainer.shap_values(X_test_scalled.iloc[0:1000,:], nsamples=1000)

# %%
shap.summary_plot(shap_values_norm, X_test_scalled.iloc[0:1000,:], feature_names=X_train_scalled.columns)

# %%
shap_values = explainer(X_test_scalled.iloc[0:1000,:])

# %%
shap.summary_plot(shap_values_norm, X_test_scalled.iloc[0:1000,:], plot_type='bar', \
                  feature_names=X_train_scalled.columns, title = "SHAP Value Summary", max_display=20)

# %% [markdown]
# <br/>Наиболее важными признаками являются lifetime, freq_fund, fundtime, funding_total_usd, в меньшей степени отдельные страны и категории.
# <br/>Чем меньше значение lifetime, тем выше вероятность принадлежности к классу closed, чем ниже значение freq_fund, тем выше вероятность принадлежности к классу operating.
